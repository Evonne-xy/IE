# %%
import pandas as pd
import csv

suburb = pd.read_csv("suburb_list (1).csv")

# %%
suburb.columns = ['index','suburb_name']

# %%
suburb.suburb_name
# Out:
# 0              DOVETON
# 1             WANTIRNA
# 2              MITCHAM
# 3             BURNSIDE
# 4          WESTMEADOWS
#             ...
# 157          RIPPONLEA
# 158         GARDENVALE
# 159          EAGLEMONT
# 160    BAYSWATER NORTH
# 161        SOUTH YARRA
# Name: suburb_name, Length: 162, dtype: object

# %%
list1 = list(suburb.suburb_name)

# %%
list1
# Out:
# ['DOVETON',
#  'WANTIRNA',
#  'MITCHAM',
#  'BURNSIDE',
#  'WESTMEADOWS',
#  'BAYSWATER',
#  'CHELTENHAM',
#  'COBURG',
#  'BEAUMARIS',
#  'MOOROOLBARK',
#  'MORDIALLOC',
#  'CHADSTONE',
#  'KINGSBURY',
#  'HEATHMONT',
#  'EPPING',
#  'RINGWOOD',
#  'DONCASTER',
#  'BUNDOORA',
#  'ORMOND',
#  'CLAYTON',
#  'HILLSIDE',
#  'BENTLEIGH',
#  'GOWANBRAE',
#  'DANDENONG',
#  'ABBOTSFORD',
#  'GREENSBOROUGH',
#  'BRUNSWICK WEST',
#  'SEABROOK',
#  'GREENVALE',
#  'FAWKNER',
#  'MAIDSTONE',
#  'ALTONA',
#  'CRAIGIEBURN',
#  'BRUNSWICK',
#  'VIEWBANK',
#  'KNOXFIELD',
#  'PRESTON',
#  'RESERVOIR',
#  'RICHMOND',
#  'PLENTY',
#  'PARKDALE',
#  'MURRUMBEENA',
#  'MULGRAVE',
#  'WINDSOR',
#  'CROYDON',
#  'BALWYN',
#  'MACLEOD',
#  'MENTONE',
#  'BRAYBROOK',
#  'NEWPORT',
#  'FOOTSCRAY',
#  'ROWVILLE',
#  'SPRINGVALE',
#  'HADFIELD',
#  'SUNSHINE',
#  'HIGHETT',
#  'BROADMEADOWS',
#  'KEYSBOROUGH',
#  'BLACKBURN',
#  'GLENROY',
#  'BURWOOD',
#  'FITZROY',
#  'CARNEGIE',
#  'TRUGANINA',
# ...

# %%
suburb_final = []
for item in list1:
    
    item = item + " Victoria"
    suburb_final.append(item)

# %%
suburb_final
# Out:
# ['DOVETON Victoria',
#  'WANTIRNA Victoria',
#  'MITCHAM Victoria',
#  'BURNSIDE Victoria',
#  'WESTMEADOWS Victoria',
#  'BAYSWATER Victoria',
#  'CHELTENHAM Victoria',
#  'COBURG Victoria',
#  'BEAUMARIS Victoria',
#  'MOOROOLBARK Victoria',
#  'MORDIALLOC Victoria',
#  'CHADSTONE Victoria',
#  'KINGSBURY Victoria',
#  'HEATHMONT Victoria',
#  'EPPING Victoria',
#  'RINGWOOD Victoria',
#  'DONCASTER Victoria',
#  'BUNDOORA Victoria',
#  'ORMOND Victoria',
#  'CLAYTON Victoria',
#  'HILLSIDE Victoria',
#  'BENTLEIGH Victoria',
#  'GOWANBRAE Victoria',
#  'DANDENONG Victoria',
#  'ABBOTSFORD Victoria',
#  'GREENSBOROUGH Victoria',
#  'BRUNSWICK WEST Victoria',
#  'SEABROOK Victoria',
#  'GREENVALE Victoria',
#  'FAWKNER Victoria',
#  'MAIDSTONE Victoria',
#  'ALTONA Victoria',
#  'CRAIGIEBURN Victoria',
#  'BRUNSWICK Victoria',
#  'VIEWBANK Victoria',
#  'KNOXFIELD Victoria',
#  'PRESTON Victoria',
#  'RESERVOIR Victoria',
#  'RICHMOND Victoria',
#  'PLENTY Victoria',
# ...

# %%
df_final = pd.DataFrame()

# %%
df_final["suburb"] = suburb_final

# %%
df_final
# Out:
#                        suburb
# 0            DOVETON Victoria
# 1           WANTIRNA Victoria
# 2            MITCHAM Victoria
# 3           BURNSIDE Victoria
# 4        WESTMEADOWS Victoria
# ..                        ...
# 157        RIPPONLEA Victoria
# 158       GARDENVALE Victoria
# 159        EAGLEMONT Victoria
# 160  BAYSWATER NORTH Victoria
# 161      SOUTH YARRA Victoria
#
# [162 rows x 1 columns]

# %%
df_final.to_csv (r'suburb_name.csv', index = False, header=True)
